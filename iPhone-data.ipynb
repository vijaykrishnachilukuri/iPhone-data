# %%
# importing necessary libraries
import pandas as pd
import seaborn as sns
pd.set_option('display.max_colwidth', None)
#pd.set_option('display.max_rows', None)

# %%
#importing the csv file directly fron the GIT repository
url = 'https://raw.githubusercontent.com/darshilparmar/python-for-data-engineering/main/1.%20iPhone%20Data%20Analysis%20Project/Data/apple_products.csv'

# %%
df = pd.read_csv (url)

# %%
df.shape
# Out:
# (62, 11)

# %%
#df.head(10)
df.loc[:10]
# Out:
#                                                                 Product Name  \
# 0                                          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1                                   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2                                       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3                                            APPLE iPhone 8 (Silver, 256 GB)
# 4                                              APPLE iPhone 8 (Gold, 256 GB)
# 5                                        APPLE iPhone 8 Plus (Silver, 64 GB)
# 6                                    APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 7                                        APPLE iPhone 8 (Space Grey, 256 GB)
# 8                                        APPLE iPhone XS Max (Silver, 64 GB)
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)
# 10          Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)
#
# ...

# %%
##need to check this again##
#df.tail(10)
df.loc[df.index[-10:], :]
# Out:
#                        Product Name  \
# 52   APPLE iPhone SE (White, 64 GB)
# 53  APPLE iPhone SE (Black, 128 GB)
# 54  APPLE iPhone SE (White, 128 GB)
# 55    APPLE iPhone SE (Red, 128 GB)
# 56  APPLE iPhone 11 (Black, 128 GB)
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                                                                       Product URL  \
# 52   https://www.flipkart.com/apple-iphone-se-white-64-gb/p/itma00a19e11c81b?pid=MOBFWQ6BGWDVGF3E
# 53  https://www.flipkart.com/apple-iphone-se-black-128-gb/p/itma9285ccc6af28?pid=MOBFWQ6BHUEVZPXD
# 54  https://www.flipkart.com/apple-iphone-se-white-128-gb/p/itmc2a0f593a4ad8?pid=MOBFWQ6BJEHMUUZY
# 55    https://www.flipkart.com/apple-iphone-se-red-128-gb/p/itma4202509da171?pid=MOBFWQ6BJTVFKPEJ
# ...

# %%
#checking null values
df.isnull().sum()
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64

# %%
#checking datatypes of columns
df.dtypes
# Out:
# Product Name            object
# Product URL             object
# Brand                   object
# Sale Price               int64
# Mrp                      int64
# Discount Percentage      int64
# Number Of Ratings        int64
# Number Of Reviews        int64
# Upc                     object
# Star Rating            float64
# Ram                     object
# dtype: object

# %%
df.describe()
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# ...

# %%
df[df['Sale Price']==140900]
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                                                                                  Product URL  \
# 24        https://www.flipkart.com/apple-iphone-12-pro-silver-512-gb/p/itm0ccf9fc219a71?pid=MOBFWBYZ5UY6ZBVA
# 41  https://www.flipkart.com/apple-iphone-12-pro-pacific-blue-512-gb/p/itm8a39d6779b04e?pid=MOBFWBYZTHSXKMGW
#
#     Brand  Sale Price     Mrp  Discount Percentage  Number Of Ratings  \
# 24  Apple      140900  149900                    6                542
# 41  Apple      140900  149900                    6                545
#
#     Number Of Reviews               Upc  Star Rating   Ram
# 24                 42  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41                 42  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
df[df['Sale Price']==29999]
# Out:
#                       Product Name  \
# 52  APPLE iPhone SE (White, 64 GB)
# 57  APPLE iPhone SE (Black, 64 GB)
#
#                                                                                      Product URL  \
# 52  https://www.flipkart.com/apple-iphone-se-white-64-gb/p/itma00a19e11c81b?pid=MOBFWQ6BGWDVGF3E
# 57  https://www.flipkart.com/apple-iphone-se-black-64-gb/p/itm4d3d5718a5c95?pid=MOBFWQ6BR3MK7AUG
#
#     Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# 52  Apple       29999  39900                   24              95807
# 57  Apple       29999  39900                   24              95909
#
#     Number Of Reviews               Upc  Star Rating   Ram
# 52               8154  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 57               8161  MOBFWQ6BR3MK7AUG          4.5  4 GB

# %%
#need refined code
df['Product'] = df['Product Name'].str.split('(').str.get(0).str.strip('APPLE')
df['Color'] = df['Product Name'].str.split('(').str.get(1).str.strip().str.split(',').str.get(0).str.strip()
df['Storage'] = df['Product Name'].str.split('(').str.get(1).str.strip().str.split(',').str.get(1).str.strip(')')
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                                                                               Product URL  \
# 0         https://www.flipkart.com/apple-iphone-8-plus-gold-64-gb/p/itmexrgvuzgzttzh?pid=MOBEXRGV7EHHTGUH
# 1  https://www.flipkart.com/apple-iphone-8-plus-space-grey-256-gb/p/itmexrgvzkbyqgtf?pid=MOBEXRGVAC6TJT4F
# 2      https://www.flipkart.com/apple-iphone-8-plus-silver-256-gb/p/itmexrgvxatuyrqw?pid=MOBEXRGVGETABXWZ
# 3           https://www.flipkart.com/apple-iphone-8-silver-256-gb/p/itmexrgvae48gzhp?pid=MOBEXRGVMZWUHCBA
# 4             https://www.flipkart.com/apple-iphone-8-gold-256-gb/p/itmexrgv8bvfbzgw?pid=MOBEXRGVPK7PFEJZ
#
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                                                Product Name  \
# 9  Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)
#
#                                                                                                                           Product URL  \
# 9  https://www.flipkart.com/apple-iphone-xr-product-red-128-gb-includes-earpods-power-adapter/p/itmf9z7zbkvjzegf?pid=MOBF9Z7ZHQC23PWQ
#
#    Brand  Sale Price    Mrp  Discount Percentage  Number Of Ratings  \
# 9  Apple       41999  52900                   20              79512
#
#    Number Of Reviews               Upc  Star Rating   Ram          Product  \
# 9               6796  MOBF9Z7ZHQC23PWQ          4.6  4 GB  pple iPhone XR
#
#   Color Storage
# 9           NaN

# %%
df.loc[9, 'Color']= 'RED'
df.loc[9, 'Storage'] = '128 GB'
df.loc[9,'Product'] = 'iPhone XR'
df.loc[9]
# Out:
# Product Name                                                                     Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)
# Product URL            https://www.flipkart.com/apple-iphone-xr-product-red-128-gb-includes-earpods-power-adapter/p/itmf9z7zbkvjzegf?pid=MOBF9Z7ZHQC23PWQ
# Brand                                                                                                                                               Apple
# Sale Price                                                                                                                                          41999
# Mrp                                                                                                                                                 52900
# Discount Percentage                                                                                                                                    20
# ...

# %%
df.head(10)
# Out:
#                                                                Product Name  \
# 0                                         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1                                  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2                                      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3                                           APPLE iPhone 8 (Silver, 256 GB)
# 4                                             APPLE iPhone 8 (Gold, 256 GB)
# 5                                       APPLE iPhone 8 Plus (Silver, 64 GB)
# 6                                   APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 7                                       APPLE iPhone 8 (Space Grey, 256 GB)
# 8                                       APPLE iPhone XS Max (Silver, 64 GB)
# 9  Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)
#
# ...

# %%
df.columns
# Out:
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Discount Percentage', 'Number Of Ratings', 'Number Of Reviews', 'Upc',
#        'Star Rating', 'Ram', 'Product', 'Color', 'Storage'],
#       dtype='object')

# %%
df.reindex(columns=['Brand', 'Product', 'Color', 'Ram', 'Storage', 'Star Rating', 'Number Of Ratings','Number Of Reviews', 'Sale Price', \
           'Mrp', 'Discount Percentage', 'Upc', 'Product Name', 'Product URL'])
# Out:
#     Brand              Product           Color   Ram  Storage  Star Rating  \
# 0   Apple       iPhone 8 Plus             Gold  2 GB    64 GB          4.6
# 1   Apple       iPhone 8 Plus       Space Grey  2 GB   256 GB          4.6
# 2   Apple       iPhone 8 Plus           Silver  2 GB   256 GB          4.6
# 3   Apple            iPhone 8           Silver  2 GB   256 GB          4.5
# 4   Apple            iPhone 8             Gold  2 GB   256 GB          4.5
# 5   Apple       iPhone 8 Plus           Silver  2 GB    64 GB          4.6
# 6   Apple       iPhone 8 Plus       Space Grey  2 GB    64 GB          4.6
# 7   Apple            iPhone 8       Space Grey  2 GB   256 GB          4.5
# 8   Apple       iPhone XS Max           Silver  4 GB    64 GB          4.6
# 9   Apple            iPhone XR             RED  4 GB   128 GB          4.6
# 10  Apple      pple iPhone XR            Black  4 GB    64 GB          4.6
# ...

# %%
df['Product'].unique()
# Out:
# array([' iPhone 8 Plus ', ' iPhone 8 ', ' iPhone XS Max ', 'iPhone XR',
#        'pple iPhone XR ', ' iPhone 11 Pro Max ', ' iPhone 11 Pro ',
#        'pple iPhone SE ', ' iPhone 12 Pro ', ' iPhone 12 Pro Max ',
#        ' iPhone 12 Mini ', ' iPhone 12 ', ' iPhone 11 ', ' iPhone SE '],
#       dtype=object)

# %%
sns.pairplot(df)
